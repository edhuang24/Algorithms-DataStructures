# %%
import matplotlib.pyplot as plt
import numpy as np
objects = ('ads', 'ga', 'forms', 'so', 'conditions', 'segments', 'content')
y_pos = np.arange(len(objects))
performance = [1934, 694, 868, 956, 1718, 1799, 1801]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Count')
plt.title('Config usage')
 
plt.show()
